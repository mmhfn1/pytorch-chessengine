# %%
# !pip install torch pytorch-lightning python-chess
# Out:
# Requirement already satisfied: torch in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (2.5.1)
# Requirement already satisfied: pytorch-lightning in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (2.5.0.post0)
# Requirement already satisfied: python-chess in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (1.999)
# Requirement already satisfied: filelock in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: tqdm>=4.57.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from pytorch-lightning) (4.66.5)
# Requirement already satisfied: PyYAML>=5.4 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from pytorch-lightning) (1.6.1)
# Requirement already satisfied: packaging>=20.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from pytorch-lightning) (24.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from pytorch-lightning) (0.11.9)
# Requirement already satisfied: chess<2,>=1 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from python-chess) (1.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.11.2)
# Requirement already satisfied: setuptools in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (72.1.0)
# Requirement already satisfied: numpy>1.20.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from torchmetrics>=0.7.0->pytorch-lightning) (2.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.17.1)
# Requirement already satisfied: idna>=2.0 in /home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.8)

# %%
import math
import random
import logging
import datetime
from typing import List, Tuple, Dict
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import chess
import chess.pgn

# Configuration

logging.basicConfig(level=logging.DEBUG, format='%(asctime)s [%(levelname)s] %(message)s')

# Hyperparameters
NUM_SELFPLAY_GAMES = 2         # Number of games per training epoch
MAX_MOVES_PER_GAME = 500       # Safety limit on moves
DISCOUNT_FACTOR = 0.99
LR = 1e-3
PPO_EPOCHS = 3
BATCH_SIZE = 32
EPS_CLIP = 0.2
ENTROPY_BONUS = 0.01
MCTS_SIMULATIONS = 32
REWARD_WIN = 1.0
REWARD_LOSS = -1.0
REWARD_DRAW = 0.0

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logging.info(f"Using device: {DEVICE}")

# Transformer parameters
BOARD_FEATURES = 13   # Channels for board encoding
EMBED_DIM = 128       # Transformer embedding dimension
NUM_HEADS = 4         # Transformer multi-head attention
NUM_LAYERS = 2        # Number of Transformer encoder layers
FFN_HIDDEN = 256      # Hidden size in feed-forward network
DROPOUT = 0.1

# Action space: 8×8×8×8 = 4096
ACTION_SPACE_SIZE = 64 * 64
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f95ea4e9ad0>>
# Traceback (most recent call last):
#   File "/home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# 2025-01-03 18:47:16,465 [INFO] Using device: cuda

# %%
# Board to tensor encoding and decoding

def board_to_tensor(board: chess.Board) -> torch.Tensor:
    """
    Encode the chess.Board into a [13, 8, 8] tensor:
      - 6 channels for white pieces (P, N, B, R, Q, K)
      - 6 channels for black pieces (p, n, b, r, q, k)
      - 1 channel for side to move
    """
    t = torch.zeros((BOARD_FEATURES, 8, 8), dtype=torch.float32)
    for square, piece in board.piece_map().items():
        row = 7 - (square // 8)
        col = square % 8
        channel = None
        if piece.color == chess.WHITE:
            if piece.piece_type == chess.PAWN:
                channel = 0
            elif piece.piece_type == chess.KNIGHT:
                channel = 1
            elif piece.piece_type == chess.BISHOP:
                channel = 2
            elif piece.piece_type == chess.ROOK:
                channel = 3
            elif piece.piece_type == chess.QUEEN:
                channel = 4
            elif piece.piece_type == chess.KING:
                channel = 5
        else:
            if piece.piece_type == chess.PAWN:
                channel = 6
            elif piece.piece_type == chess.KNIGHT:
                channel = 7
            elif piece.piece_type == chess.BISHOP:
                channel = 8
            elif piece.piece_type == chess.ROOK:
                channel = 9
            elif piece.piece_type == chess.QUEEN:
                channel = 10
            elif piece.piece_type == chess.KING:
                channel = 11

        if channel is not None:
            t[channel, row, col] = 1.0

    if board.turn == chess.WHITE:
        t[12, :, :] = 1.0

    return t


def move_to_index(move: chess.Move) -> int:
    # Map a python-chess Move to an index in [0..4095].
    # from_square in [0..63], to_square in [0..63].
    # index = from_square * 64 + to_square
    return move.from_square * 64 + move.to_square


def index_to_move(index: int, board: chess.Board) -> chess.Move:
    # Inverse of move_to_index. We decode (from_square, to_square)
    # and construct a python-chess Move. For promotions, default to queen.
    from_sq = index // 64
    to_sq = index % 64
    move = chess.Move(from_sq, to_sq)
    # Try adding promotion if it's a pawn move to the back rank
    if move not in board.legal_moves:
        # If it's a pawn move that might require promotion:
        if (chess.square_rank(to_sq) in [0, 7] 
            and board.piece_at(from_sq) is not None
            and board.piece_at(from_sq).piece_type == chess.PAWN):
            move = chess.Move(from_sq, to_sq, promotion=chess.QUEEN)
    return move


def chess_outcome_to_reward(outcome: chess.Outcome) -> float:
    # Convert a python-chess outcome to a numeric reward from White's perspective.
    if outcome.winner is None:
        return REWARD_DRAW
    elif outcome.winner == chess.WHITE:
        return REWARD_WIN
    else:
        return REWARD_LOSS

# %%
# Transformer Based NN

class PositionalEncoding2D(nn.Module):
    # 2D positional encoding for an 8x8 board.
    # Producing an [embed_dim, height, width] embedding that can be added to the board embeddings.
    def __init__(self, embed_dim=128, height=8, width=8):
        super().__init__()
        self.embed_dim = embed_dim
        self.height = height
        self.width = width

        d2 = embed_dim // 2  # E.g., 128 -> 64
        pe = torch.zeros(embed_dim, height, width)  # shape: [embed_dim, 8, 8]

        # We only need d2/2 "frequencies" for sine and cosine
        num_freqs = d2 // 2  # e.g., 64//2=32
        div_term = torch.exp(torch.arange(0, num_freqs, 1) * -(math.log(10000.0) / num_freqs))

        # Positions along rows & cols
        pos_y = torch.arange(0, height).unsqueeze(1)  # shape: [8,1]
        pos_x = torch.arange(0, width).unsqueeze(1)   # shape: [8,1]

        pe_y = torch.zeros(d2, height)
        pe_x = torch.zeros(d2, width)

        # Fill in row-based sines/cosines
        for idx in range(num_freqs):
            i_sin = 2 * idx
            i_cos = 2 * idx + 1
            pe_y[i_sin, :] = torch.sin(pos_y[:, 0] * div_term[idx])
            pe_y[i_cos, :] = torch.cos(pos_y[:, 0] * div_term[idx])

        # Fill in col-based sines/cosines (occupies the second half of channels)
        for idx in range(num_freqs):
            i_sin = 2 * idx
            i_cos = 2 * idx + 1
            pe_x[i_sin, :] = torch.sin(pos_x[:, 0] * div_term[idx])
            pe_x[i_cos, :] = torch.cos(pos_x[:, 0] * div_term[idx])

        # Combine them: first half for rows, second half for cols
        for y in range(height):
            for x in range(width):
                pe[:d2, y, x] = pe_y[:, y]
                pe[d2:, y, x] = pe_x[:, x]

        self.register_buffer('pe', pe)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x shape: [batch_size, embed_dim, height, width]
        return x + self.pe.unsqueeze(0).to(x.device)


class TransformerChessNet(nn.Module):
    # A Transformer-based model for chess. We flatten the 8x8 to a sequence of 64 tokens,
    # each token having a dimension of 'embed_dim'. Then we pass it through a Transformer
    # encoder to produce a final representation used by the policy & value heads.
    # Policy dimension: 4096
    # Value dimension: 1
    def __init__(self, name: str):
        super().__init__()
        self.name = name

        # Initial encoding: Convert [13,8,8] to [embed_dim, 8,8] via a simple Conv
        self.initial_conv = nn.Conv2d(BOARD_FEATURES, EMBED_DIM, kernel_size=3, padding=1)
        self.pos_enc = PositionalEncoding2D(embed_dim=EMBED_DIM, height=8, width=8)

        # Flatten 8x8 into sequence of length 64
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=EMBED_DIM,
            nhead=NUM_HEADS,
            dim_feedforward=FFN_HIDDEN,
            dropout=DROPOUT,
            activation='relu',
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=NUM_LAYERS)

        # Policy & value heads
        self.policy_head = nn.Linear(EMBED_DIM, ACTION_SPACE_SIZE)
        self.value_head = nn.Linear(EMBED_DIM, 1)

    def forward(self, x: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:
        # x shape: [batch_size, 13, 8, 8]
        # Returns policy_logits: [batch_size, 4096]
        # value: [batch_size, 1]
        out = self.initial_conv(x)  # [batch_size, embed_dim, 8, 8]
        out = self.pos_enc(out)     # add positional encoding

        # Flatten to [batch_size, 64, embed_dim]
        bsz, edim, h, w = out.shape
        out = out.permute(0, 2, 3, 1).contiguous()
        out = out.view(bsz, h*w, edim)  # [B, 64, embed_dim]

        out = self.transformer(out)     # [B, 64, embed_dim]

        # Pool (average) to get a single embedding
        pooled = out.mean(dim=1)  # [B, embed_dim]

        policy_logits = self.policy_head(pooled)  # [B, 4096]
        value = torch.tanh(self.value_head(pooled)) # [B, 1]

        return policy_logits, value

# %%
# MCTS

class MCTSNode:
    def __init__(self, board: chess.Board, parent=None):
        self.board = board
        self.parent = parent
        self.children: Dict[chess.Move, "MCTSNode"] = {}
        self.visit_count = 0
        self.value_sum = 0.0
        self.prior = 0.0

    def is_leaf(self):
        return len(self.children) == 0

    def expand(self, moves: List[chess.Move], priors: torch.Tensor):
        # Expand for each legal move
        for move in moves:
            child_board = self.board.copy()
            child_board.push(move)
            idx = move_to_index(move)
            p = priors[idx].item() if idx < ACTION_SPACE_SIZE else 0.0
            child_node = MCTSNode(child_board, parent=self)
            child_node.prior = p
            self.children[move] = child_node

    def value(self):
        if self.visit_count == 0:
            return 0.0
        return self.value_sum / self.visit_count

    def ucb_score(self, total_visit_count, c_puct=1.0):
        return self.value() + c_puct * self.prior * math.sqrt(total_visit_count) / (1 + self.visit_count)


def mcts_search(root: MCTSNode, net: nn.Module, simulations=MCTS_SIMULATIONS):
    # Basic MCTS: For each simulation, we traverse down, expand the leaf, evaluate,
    # and backpropagate the result.
    net.eval()
    for sim in range(simulations):
        node = root
        # Selection
        while not node.is_leaf() and not node.board.is_game_over():
            best_move, best_score, best_child = None, -float("inf"), None
            for move, child in node.children.items():
                score = child.ucb_score(node.visit_count)
                if score > best_score:
                    best_score = score
                    best_move = move
                    best_child = child
            node = best_child

        # Expansion
        if not node.board.is_game_over():
            board_tensor = board_to_tensor(node.board).unsqueeze(0).to(DEVICE)
            with torch.no_grad():
                policy_logits, value = net(board_tensor)
            policy_logits = F.softmax(policy_logits[0], dim=-1)  # [4096]
            legal_moves = list(node.board.legal_moves)
            node.expand(legal_moves, policy_logits)

        # Evaluation
        if node.board.is_game_over():
            outcome = node.board.outcome()
            current_value = chess_outcome_to_reward(outcome)
        else:
            current_value = value.item()

        # Backpropagation
        while node is not None:
            node.visit_count += 1
            node.value_sum += current_value
            node = node.parent
            current_value = -current_value

        logging.debug(f"MCTS simulation {sim+1}/{simulations} done")


def select_move_mcts(board: chess.Board, net: nn.Module, simulations=MCTS_SIMULATIONS, temperature=1.0) -> chess.Move:
    # Build a root node for the given board, expand once from the net, run MCTS,
    # then pick a move from children with probability proportional to visit counts.
    root = MCTSNode(board.copy())
    with torch.no_grad():
        board_tensor = board_to_tensor(board).unsqueeze(0).to(DEVICE)
        policy_logits, value = net(board_tensor)
    policy_logits = F.softmax(policy_logits[0], dim=-1)
    legal_moves = list(board.legal_moves)
    root.expand(legal_moves, policy_logits)

    # Run MCTS
    mcts_search(root, net, simulations=simulations)

    # pick child with probability = visit_count^(1/temperature)
    visit_counts = torch.tensor([child.visit_count for child in root.children.values()], dtype=torch.float32)
    if visit_counts.sum() == 0:
        # fallback
        logging.debug("No visit counts in MCTS root children, returning None.")
        return None

    if temperature < 1e-8:
        move_index = torch.argmax(visit_counts).item()
    else:
        probs = visit_counts ** (1.0 / temperature)
        move_index = torch.multinomial(probs, 1).item()

    selected_move = list(root.children.keys())[move_index]
    logging.debug(f"MCTS selected move: {selected_move}")
    return selected_move

# %%
# Replay Buffer

class ReplayBuffer:
    def __init__(self):
        self.states = []
        self.actions = []
        self.log_probs = []
        self.values = []
        self.rewards = []
        self.dones = []

    def add(self, state, action, log_prob, value, reward, done):
        self.states.append(state)
        self.actions.append(action)
        self.log_probs.append(log_prob)
        self.values.append(value)
        self.rewards.append(reward)
        self.dones.append(done)

    def clear(self):
        self.states.clear()
        self.actions.clear()
        self.log_probs.clear()
        self.values.clear()
        self.rewards.clear()
        self.dones.clear()

    def size(self):
        return len(self.states)

# %%
# PPO Update

def ppo_update(net: nn.Module, optimizer: optim.Optimizer,
               states: torch.Tensor, actions: torch.Tensor,
               old_log_probs: torch.Tensor,
               returns: torch.Tensor, advantages: torch.Tensor):
    # Perform one epoch of PPO updates on the given batch.
    
    # shuffle
    indices = torch.randperm(states.size(0)).to(DEVICE)
    for start in range(0, states.size(0), BATCH_SIZE):
        end = start + BATCH_SIZE
        batch_idx = indices[start:end]

        batch_states = states[batch_idx]
        batch_actions = actions[batch_idx]
        batch_old_log_probs = old_log_probs[batch_idx]
        batch_returns = returns[batch_idx]
        batch_advantages = advantages[batch_idx]

        policy_logits, values = net(batch_states)  # policy_logits: [bs, 4096], values: [bs,1]

        policy_log_probs = F.log_softmax(policy_logits, dim=-1)  # [bs, 4096]
        new_log_probs = policy_log_probs.gather(1, batch_actions.unsqueeze(-1)).squeeze(-1)  # [bs]

        ratio = torch.exp(new_log_probs - batch_old_log_probs)

        surr1 = ratio * batch_advantages
        surr2 = torch.clamp(ratio, 1.0 - EPS_CLIP, 1.0 + EPS_CLIP) * batch_advantages
        policy_loss = -torch.min(surr1, surr2).mean()

        value_loss = F.mse_loss(values.squeeze(-1), batch_returns)

        entropy = -(policy_log_probs * torch.exp(policy_log_probs)).sum(dim=-1).mean()

        loss = policy_loss + 0.5 * value_loss - ENTROPY_BONUS * entropy

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    logging.debug(f"PPO update done with {states.size(0)} samples.")

# %%
# CHessBot Class

class ChessBot:
    def __init__(self, name: str):
        self.name = name
        self.net = TransformerChessNet(name).to(DEVICE)
        logging.debug(f"{name}: Model initialized. First parameter device: {next(self.net.parameters()).device}")
        self.optimizer = optim.Adam(self.net.parameters(), lr=LR)
        self.replay = ReplayBuffer()

    def select_move(self, board: chess.Board) -> Tuple[chess.Move, float, float]:
        # Uses MCTS to select a move, returns (move, log_prob, value).
        self.net.eval()
        move = select_move_mcts(board, self.net, simulations=MCTS_SIMULATIONS, temperature=1.0)
        if move is None:
            return None, 0.0, 0.0

        # compute log_prob and value from the net
        board_tensor = board_to_tensor(board).unsqueeze(0).to(DEVICE)
        with torch.no_grad():
            policy_logits, value = self.net(board_tensor)
        policy_log_probs = F.log_softmax(policy_logits, dim=-1)  # [1, 4096]

        move_idx = move_to_index(move)
        log_prob = policy_log_probs[0, move_idx].item()
        val = value[0].item()
        return move, log_prob, val

    def train_on_replay(self):
        size = self.replay.size()
        logging.debug(f"{self.name}: Replay buffer size = {size}")
        if size == 0:
            return

        states = torch.stack(self.replay.states).to(DEVICE)  # [N, 13, 8, 8]
        actions = torch.tensor(self.replay.actions, dtype=torch.long).to(DEVICE)  # [N]
        log_probs_old = torch.tensor(self.replay.log_probs, dtype=torch.float32).to(DEVICE)  # [N]
        values = torch.tensor(self.replay.values, dtype=torch.float32).to(DEVICE)  # [N]
        rewards = torch.tensor(self.replay.rewards, dtype=torch.float32).to(DEVICE)  # [N]
        dones = torch.tensor(self.replay.dones, dtype=torch.float32).to(DEVICE)  # [N]

        # Compute returns and advantages (simple GAE)
        returns = []
        advantages = []
        gae = 0.0
        for i in reversed(range(size)):
            if i == size - 1 or dones[i] == 1.0:
                delta = rewards[i] - values[i]
                gae = delta
            else:
                delta = rewards[i] + DISCOUNT_FACTOR * values[i+1] - values[i]
                gae = delta + DISCOUNT_FACTOR * gae
            advantages.insert(0, gae)
            returns.insert(0, gae + values[i])

        returns = torch.tensor(returns, dtype=torch.float32).to(DEVICE)
        advantages = torch.tensor(advantages, dtype=torch.float32).to(DEVICE)
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        for _ in range(PPO_EPOCHS):
            ppo_update(self.net, self.optimizer, states, actions,
                       log_probs_old, returns, advantages)

        self.replay.clear()
        logging.debug(f"{self.name}: Completed training on replay.")

# %%
#Self Play

def play_selfplay_game(bot_white: ChessBot, bot_black: ChessBot, game_id: int):
    board = chess.Board()

    # Create a PGN game object with accurate headers
    pgn_game = chess.pgn.Game()
    pgn_game.headers["Event"] = f"Self-Play Game #{game_id}"
    pgn_game.headers["Site"] = "Local Machine"
    pgn_game.headers["Date"] = datetime.date.today().strftime("%Y.%m.%d")
    pgn_game.headers["Round"] = str(game_id)
    pgn_game.headers["White"] = bot_white.name
    pgn_game.headers["Black"] = bot_black.name
    pgn_game.headers["Result"] = "*"  # provisional

    node = pgn_game

    states_w, actions_w, log_probs_w, vals_w, rewards_w, dones_w = [], [], [], [], [], []
    states_b, actions_b, log_probs_b, vals_b, rewards_b, dones_b = [], [], [], [], [], []

    move_count = 0

    while not board.is_game_over() and move_count < MAX_MOVES_PER_GAME:
        move_count += 1
        if board.turn == chess.WHITE:
            move, log_p, val = bot_white.select_move(board)
            if move is None:
                logging.debug("White has no move. Breaking.")
                break
            states_w.append(board_to_tensor(board))
            a_idx = move_to_index(move)
            actions_w.append(a_idx)
            log_probs_w.append(log_p)
            vals_w.append(val)
            rewards_w.append(0.0)
            dones_w.append(0.0)

            board.push(move)
            node = node.add_variation(move)
        else:
            move, log_p, val = bot_black.select_move(board)
            if move is None:
                logging.debug("Black has no move. Breaking.")
                break
            states_b.append(board_to_tensor(board))
            a_idx = move_to_index(move)
            actions_b.append(a_idx)
            log_probs_b.append(log_p)
            vals_b.append(val)
            rewards_b.append(0.0)
            dones_b.append(0.0)

            board.push(move)
            node = node.add_variation(move)

    outcome = board.outcome()
    final_reward_white = 0.0
    if outcome is not None:
        final_reward_white = chess_outcome_to_reward(outcome)

    # White gets final_reward_white, Black gets -final_reward_white
    for i in range(len(rewards_w)):
        rewards_w[i] = final_reward_white
        if i == len(rewards_w) - 1:
            dones_w[i] = 1.0
    for i in range(len(rewards_b)):
        rewards_b[i] = -final_reward_white
        if i == len(rewards_b) - 1:
            dones_b[i] = 1.0

    # Add to replay buffers
    for i in range(len(states_w)):
        bot_white.replay.add(
            states_w[i], actions_w[i], log_probs_w[i],
            vals_w[i], rewards_w[i], dones_w[i]
        )
    for i in range(len(states_b)):
        bot_black.replay.add(
            states_b[i], actions_b[i], log_probs_b[i],
            vals_b[i], rewards_b[i], dones_b[i]
        )

    # Update the PGN "Result"
    if board.is_game_over() and outcome is not None:
        if outcome.winner == chess.WHITE:
            pgn_game.headers["Result"] = "1-0"
        elif outcome.winner == chess.BLACK:
            pgn_game.headers["Result"] = "0-1"
        else:
            pgn_game.headers["Result"] = "1/2-1/2"
    else:
        pgn_game.headers["Result"] = "*"

    fen_str = board.fen()
    pgn_str = str(pgn_game)
    logging.info(f"Game #{game_id} finished. FEN: {fen_str}")
    logging.info(f"PGN:\n{pgn_str}")

    # Save PGN and FEN
    with open(f"game_{game_id}.pgn", "w") as f:
        f.write(pgn_str + "\n")
    with open(f"game_{game_id}.fen", "w") as f:
        f.write(fen_str + "\n")

# %%
# Main Loop

def main_train_loop(num_epochs=1):
    logging.info("Starting main training loop.")
    logging.debug(f"Number of epochs: {num_epochs}. Games per epoch: {NUM_SELFPLAY_GAMES}")

    bot_white = ChessBot("Transformer-Bot-White")
    bot_black = ChessBot("Transformer-Bot-Black")

    for epoch in range(num_epochs):
        logging.info(f"===== EPOCH {epoch+1}/{num_epochs} =====")
        for game_id in range(epoch * NUM_SELFPLAY_GAMES, (epoch+1) * NUM_SELFPLAY_GAMES):
            play_selfplay_game(bot_white, bot_black, game_id)

        # Train each bot
        logging.info(f"Training {bot_white.name}")
        bot_white.train_on_replay()

        logging.info(f"Training {bot_black.name}")
        bot_black.train_on_replay()

        # Additional debug: We can quickly check net parameters or
        # run a quick net forward
        logging.debug(f"{bot_white.name} param sample: {next(bot_white.net.parameters()).flatten()[0]}")
        logging.debug(f"{bot_black.name} param sample: {next(bot_black.net.parameters()).flatten()[0]}")

    logging.info("Training complete.")


if __name__ == "__main__":
    main_train_loop(num_epochs=1)
# Out:
# 2025-01-03 18:47:16,554 [INFO] Starting main training loop.
# 2025-01-03 18:47:16,555 [DEBUG] Number of epochs: 1. Games per epoch: 2
# 2025-01-03 18:47:16,814 [DEBUG] Transformer-Bot-White: Model initialized. First parameter device: cuda:0
# 2025-01-03 18:47:17,559 [DEBUG] Transformer-Bot-Black: Model initialized. First parameter device: cuda:0
# 2025-01-03 18:47:17,560 [INFO] ===== EPOCH 1/1 =====
# 2025-01-03 18:47:17,858 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:17,860 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:17,863 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:17,866 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:17,868 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:17,870 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:17,872 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:17,877 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:17,880 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:17,885 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:17,887 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:17,890 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:17,892 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:17,895 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:17,897 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:17,900 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:17,903 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:17,906 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:17,908 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:17,911 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:17,914 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:17,917 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:17,920 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:17,923 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:17,925 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:17,928 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:17,931 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:17,934 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:17,937 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:17,939 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:17,943 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:17,945 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:17,952 [DEBUG] MCTS selected move: c2c3
# 2025-01-03 18:47:17,958 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:17,960 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:17,963 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:17,965 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:17,968 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:17,971 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:17,974 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:17,977 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:17,979 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:17,981 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:17,984 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:17,986 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:17,989 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:17,991 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:17,993 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:17,995 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:17,997 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:17,999 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,001 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,003 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,005 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,007 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,010 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,013 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,015 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,018 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,020 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,024 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,027 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,030 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,033 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,035 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,036 [DEBUG] MCTS selected move: g8h6
# 2025-01-03 18:47:18,041 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,043 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,045 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,048 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,050 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,053 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,055 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,058 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,060 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,062 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,065 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,068 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,070 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,073 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,075 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,078 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,080 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,083 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,086 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,089 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,092 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,094 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,096 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,099 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,101 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,104 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,106 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,109 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,111 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,113 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,115 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,118 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,118 [DEBUG] MCTS selected move: h2h3
# 2025-01-03 18:47:18,123 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,126 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,130 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,133 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,135 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,138 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,141 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,144 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,147 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,149 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,152 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,154 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,156 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,158 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,160 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,162 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,164 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,166 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,168 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,170 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,172 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,175 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,178 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,181 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,184 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,186 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,189 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,191 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,194 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,196 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,199 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,202 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,203 [DEBUG] MCTS selected move: h8g8
# 2025-01-03 18:47:18,209 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,211 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,213 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,216 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,219 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,222 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,224 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,226 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,229 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,232 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,234 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,237 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,239 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,242 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,244 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,246 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,248 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,250 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,253 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,255 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,257 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,260 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,262 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,265 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,268 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,270 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,272 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,275 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,277 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,281 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,283 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,285 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,286 [DEBUG] MCTS selected move: h1h2
# 2025-01-03 18:47:18,292 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,294 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,297 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,299 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,301 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,303 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,307 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,309 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,312 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,314 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,316 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,319 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,321 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,325 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,390 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,393 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,396 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,398 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,402 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,404 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,406 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,408 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,412 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,415 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,417 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,419 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,422 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,424 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,426 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,428 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,431 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,433 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,434 [DEBUG] MCTS selected move: g8h8
# 2025-01-03 18:47:18,439 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,441 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,444 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,446 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,449 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,451 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,453 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,456 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,458 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,461 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,463 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,466 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,468 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,471 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,473 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,476 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,478 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,480 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,482 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,485 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,487 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,490 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,492 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,495 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,498 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,500 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,502 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,504 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,507 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,510 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,512 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,514 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,515 [DEBUG] MCTS selected move: g2g4
# 2025-01-03 18:47:18,520 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,523 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,525 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,528 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,530 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,533 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,536 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,538 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,543 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,545 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,549 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,551 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,554 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,556 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,559 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,561 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,564 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,566 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,569 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,571 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,574 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,576 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,578 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,581 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,583 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,585 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,589 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,592 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,594 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,596 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,598 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,600 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,601 [DEBUG] MCTS selected move: h8g8
# 2025-01-03 18:47:18,607 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,609 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,611 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,614 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,616 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,619 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,621 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,624 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,626 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,629 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,631 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,633 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,636 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,639 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,641 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,644 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,646 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,649 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,651 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,653 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,656 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,658 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,661 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,663 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,665 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,668 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,670 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,674 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,676 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,680 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,683 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,686 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,686 [DEBUG] MCTS selected move: f2f4
# 2025-01-03 18:47:18,692 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,694 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,697 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,699 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,701 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,704 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,706 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,708 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,710 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,713 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,716 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,719 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,722 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,724 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,726 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,729 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,732 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,735 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,738 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,740 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,744 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,747 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,750 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,753 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,757 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,759 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,762 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,765 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,768 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,771 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,774 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,777 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,778 [DEBUG] MCTS selected move: g8h8
# 2025-01-03 18:47:18,784 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,786 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,789 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,793 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,795 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,798 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,802 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,805 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,808 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,810 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,813 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,815 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,818 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,822 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,825 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,828 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,831 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,834 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,837 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,841 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,843 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,846 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,848 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,851 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,853 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:18,855 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:18,858 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:18,860 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:18,862 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:18,865 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:18,867 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:18,870 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:18,870 [DEBUG] MCTS selected move: g1f3
# 2025-01-03 18:47:18,875 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:18,878 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:18,880 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:18,883 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:18,948 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:18,952 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:18,954 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:18,956 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:18,959 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:18,961 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:18,964 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:18,966 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:18,968 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:18,970 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:18,973 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:18,975 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:18,978 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:18,981 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:18,983 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:18,985 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:18,988 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:18,991 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:18,993 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:18,995 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:18,998 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,001 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,003 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,006 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,009 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,013 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,015 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,017 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,018 [DEBUG] MCTS selected move: h8g8
# 2025-01-03 18:47:19,023 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,026 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,028 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,031 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,033 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,036 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,038 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,041 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,043 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,046 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,049 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,051 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,054 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,056 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,060 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,062 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,065 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,068 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,070 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,073 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,075 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,079 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,081 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,084 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,086 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,088 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,091 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,094 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,096 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,099 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,101 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,104 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,105 [DEBUG] MCTS selected move: f1g2
# 2025-01-03 18:47:19,109 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,112 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,114 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,117 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,119 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,122 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,125 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,128 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,130 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,133 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,135 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,137 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,141 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,143 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,146 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,149 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,153 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,156 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,159 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,161 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,164 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,166 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,169 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,171 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,174 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,177 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,179 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,182 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,184 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,186 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,189 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,191 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,192 [DEBUG] MCTS selected move: g8h8
# 2025-01-03 18:47:19,197 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,200 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,202 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,205 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,207 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,210 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,212 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,214 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,217 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,219 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,221 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,223 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,226 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,229 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,232 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,235 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,237 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,240 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,243 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,245 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,247 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,250 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,252 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,255 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,258 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,261 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,263 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,266 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,268 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,271 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,273 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,276 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,277 [DEBUG] MCTS selected move: g2h1
# 2025-01-03 18:47:19,282 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,350 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,353 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,355 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,358 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,360 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,363 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,365 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,369 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,371 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,374 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,376 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,379 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,381 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,384 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,386 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,390 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,392 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,395 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,397 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,400 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,402 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,405 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,407 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,412 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,415 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,418 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,420 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,423 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,425 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,428 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,430 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,431 [DEBUG] MCTS selected move: h8g8
# 2025-01-03 18:47:19,436 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,439 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,441 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,444 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,446 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,450 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,452 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,455 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,457 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,460 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,462 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,465 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,467 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,471 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,473 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,476 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,479 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,482 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,485 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,487 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,490 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,493 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,495 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,498 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,501 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,503 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,507 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,510 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,512 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,515 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,518 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,520 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,521 [DEBUG] MCTS selected move: e2e3
# 2025-01-03 18:47:19,529 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,532 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,535 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,538 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,540 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,543 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,546 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,549 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,553 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,555 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,558 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,560 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,563 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,566 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,569 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,571 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,575 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,577 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,580 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,582 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,584 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,587 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,590 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,592 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,595 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,597 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,600 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,603 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,606 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,610 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,613 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,615 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,616 [DEBUG] MCTS selected move: g8h8
# 2025-01-03 18:47:19,621 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,624 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,626 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,629 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,632 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,635 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,638 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,640 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,643 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,646 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,649 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,652 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,654 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,658 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,660 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,735 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,738 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,741 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,744 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,748 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,750 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,754 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,757 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,760 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,763 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,767 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,769 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,773 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,776 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,780 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,783 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,786 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,787 [DEBUG] MCTS selected move: f3h4
# 2025-01-03 18:47:19,793 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,797 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,801 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,804 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,807 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,811 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,814 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,817 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,820 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,824 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,828 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,831 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,836 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,839 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,843 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,846 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,850 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,853 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,857 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,859 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,863 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,866 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,869 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,872 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,875 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,878 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,881 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,884 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,887 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,890 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,895 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,898 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,899 [DEBUG] MCTS selected move: h8g8
# 2025-01-03 18:47:19,905 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:19,908 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:19,911 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:19,914 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:19,917 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:19,920 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:19,923 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:19,926 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:19,928 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:19,931 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:19,933 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:19,937 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:19,939 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:19,943 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:19,945 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:19,948 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:19,950 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:19,952 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:19,954 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:19,957 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:19,960 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:19,963 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:19,965 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:19,968 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:19,971 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:19,974 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:19,977 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:19,980 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:19,982 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:19,985 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:19,987 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:19,991 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:19,992 [DEBUG] MCTS selected move: h1b7
# 2025-01-03 18:47:19,998 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:20,000 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:20,003 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:20,006 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:20,009 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:20,011 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:20,015 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:20,017 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:20,021 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:20,024 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:20,094 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:20,097 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:20,101 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:20,103 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:20,107 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:20,109 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:20,112 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:20,116 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:20,120 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:20,122 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:20,125 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:20,127 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:20,131 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:20,133 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:20,137 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:20,139 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:20,142 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:20,145 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:20,148 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:20,151 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:20,155 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:20,158 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:20,158 [DEBUG] MCTS selected move: g8h8
# 2025-01-03 18:47:20,165 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:20,168 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:20,171 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:20,176 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:20,179 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:20,183 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:20,185 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:20,188 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:20,191 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:20,195 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:20,198 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:20,202 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:20,204 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:20,209 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:20,212 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:20,216 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:20,219 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:20,223 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:20,226 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:20,229 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:20,232 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:20,236 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:20,238 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:20,241 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:20,244 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:20,247 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:20,250 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:20,255 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:20,258 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:20,262 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:20,264 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:20,268 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:20,269 [DEBUG] MCTS selected move: b7h1
# 2025-01-03 18:47:20,275 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:20,278 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:20,281 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:20,285 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:20,289 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:20,291 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:20,295 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:20,298 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:20,302 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:20,305 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:20,308 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:20,311 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:20,315 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:20,319 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:20,323 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:20,325 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:20,329 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:20,332 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:20,335 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:20,337 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:20,340 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:20,343 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:20,346 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:20,349 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:20,352 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:20,354 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:20,357 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:20,361 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:20,363 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:20,366 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:20,435 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:20,438 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:20,439 [DEBUG] MCTS selected move: h8g8
# 2025-01-03 18:47:20,446 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:20,449 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:20,452 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:20,455 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:20,458 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:20,461 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:20,463 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:20,466 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:20,469 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:20,472 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:20,474 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:20,478 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:20,480 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:20,484 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:20,486 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:20,489 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:20,492 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:20,495 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:20,497 [DEBUG] MCTS simulation 19/32 done
# ...
# 2025-01-03 18:47:28,806 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:28,813 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:28,817 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:28,823 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:28,826 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:28,833 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:28,837 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:28,842 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:28,846 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:28,852 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:28,857 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:28,861 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:28,865 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:28,870 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:28,874 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:28,879 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:28,884 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:28,890 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:28,893 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:28,899 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:28,903 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:28,909 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:28,909 [DEBUG] MCTS selected move: f3a8
# 2025-01-03 18:47:28,921 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:28,925 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:28,931 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:28,944 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:28,949 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:28,953 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:28,957 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:28,960 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:28,966 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:28,969 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:29,044 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:29,048 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:29,053 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:29,056 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:29,060 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:29,064 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:29,068 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:29,071 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:29,075 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:29,079 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:29,084 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:29,088 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:29,093 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:29,097 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:29,102 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:29,106 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:29,111 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:29,114 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:29,119 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:29,122 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:29,127 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:29,130 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:29,131 [DEBUG] MCTS selected move: g8h8
# 2025-01-03 18:47:29,139 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:29,144 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:29,146 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:29,150 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:29,154 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:29,159 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:29,162 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:29,167 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:29,170 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:29,174 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:29,177 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:29,182 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:29,186 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:29,190 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:29,193 [DEBUG] MCTS simulation 15/32 done
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f95ea4e9ad0>>
# Traceback (most recent call last):
#   File "/home/mmhfn1/anaconda3/envs/py311/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# 2025-01-03 18:47:29,271 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:29,274 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:29,279 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:29,283 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:29,287 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:29,289 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:29,295 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:29,299 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:29,302 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:29,305 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:29,310 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:29,313 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:29,318 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:29,321 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:29,325 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:29,328 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:29,334 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:29,335 [DEBUG] MCTS selected move: d4d5
# 2025-01-03 18:47:29,343 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:29,346 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:29,351 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:29,354 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:29,358 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:29,362 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:29,366 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:29,370 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:29,375 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:29,378 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:29,382 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:29,386 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:29,392 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:29,395 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:29,399 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:29,402 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:29,407 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:29,410 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:29,415 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:29,419 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:29,425 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:29,428 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:29,508 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:29,511 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:29,516 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:29,519 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:29,524 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:29,527 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:29,532 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:29,535 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:29,539 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:29,542 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:29,543 [DEBUG] MCTS selected move: h8g8
# 2025-01-03 18:47:29,551 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:29,556 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:29,558 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:29,561 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:29,564 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:29,568 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:29,572 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:29,577 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:29,580 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:29,585 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:29,588 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:29,595 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:29,598 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:29,604 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:29,608 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:29,613 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:29,616 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:29,621 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:29,624 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:29,628 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:29,631 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:29,636 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:29,639 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:29,642 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:29,645 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:29,649 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:29,652 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:29,656 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:29,658 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:29,663 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:29,666 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:29,745 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:29,745 [DEBUG] MCTS selected move: a4c2
# 2025-01-03 18:47:29,754 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:29,757 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:29,761 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:29,764 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:29,770 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:29,774 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:29,778 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:29,782 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:29,786 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:29,789 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:29,793 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:29,796 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:29,801 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:29,804 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:29,809 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:29,812 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:29,819 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:29,822 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:29,826 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:29,830 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:29,833 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:29,837 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:29,841 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:29,845 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:29,849 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:29,853 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:29,856 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:29,860 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:29,864 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:29,869 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:29,873 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:29,876 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:29,877 [DEBUG] MCTS selected move: g8h8
# 2025-01-03 18:47:29,883 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:29,888 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:29,892 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:29,896 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:29,900 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:29,905 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:29,908 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:29,911 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:29,915 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:29,919 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:29,922 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:30,012 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:30,016 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:30,021 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:30,024 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:30,028 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:30,031 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:30,037 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:30,041 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:30,045 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:30,048 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:30,052 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:30,056 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:30,060 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:30,063 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:30,067 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:30,071 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:30,076 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:30,079 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:30,083 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:30,087 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:30,092 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:30,093 [DEBUG] MCTS selected move: d2c1
# 2025-01-03 18:47:30,101 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:30,104 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:30,110 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:30,114 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:30,118 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:30,121 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:30,126 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:30,129 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:30,134 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:30,140 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:30,145 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:30,148 [DEBUG] MCTS simulation 12/32 done
# 2025-01-03 18:47:30,152 [DEBUG] MCTS simulation 13/32 done
# 2025-01-03 18:47:30,155 [DEBUG] MCTS simulation 14/32 done
# 2025-01-03 18:47:30,160 [DEBUG] MCTS simulation 15/32 done
# 2025-01-03 18:47:30,237 [DEBUG] MCTS simulation 16/32 done
# 2025-01-03 18:47:30,243 [DEBUG] MCTS simulation 17/32 done
# 2025-01-03 18:47:30,246 [DEBUG] MCTS simulation 18/32 done
# 2025-01-03 18:47:30,251 [DEBUG] MCTS simulation 19/32 done
# 2025-01-03 18:47:30,255 [DEBUG] MCTS simulation 20/32 done
# 2025-01-03 18:47:30,260 [DEBUG] MCTS simulation 21/32 done
# 2025-01-03 18:47:30,265 [DEBUG] MCTS simulation 22/32 done
# 2025-01-03 18:47:30,269 [DEBUG] MCTS simulation 23/32 done
# 2025-01-03 18:47:30,273 [DEBUG] MCTS simulation 24/32 done
# 2025-01-03 18:47:30,279 [DEBUG] MCTS simulation 25/32 done
# 2025-01-03 18:47:30,282 [DEBUG] MCTS simulation 26/32 done
# 2025-01-03 18:47:30,287 [DEBUG] MCTS simulation 27/32 done
# 2025-01-03 18:47:30,290 [DEBUG] MCTS simulation 28/32 done
# 2025-01-03 18:47:30,294 [DEBUG] MCTS simulation 29/32 done
# 2025-01-03 18:47:30,297 [DEBUG] MCTS simulation 30/32 done
# 2025-01-03 18:47:30,303 [DEBUG] MCTS simulation 31/32 done
# 2025-01-03 18:47:30,306 [DEBUG] MCTS simulation 32/32 done
# 2025-01-03 18:47:30,307 [DEBUG] MCTS selected move: h8g8
# 2025-01-03 18:47:30,316 [DEBUG] MCTS simulation 1/32 done
# 2025-01-03 18:47:30,320 [DEBUG] MCTS simulation 2/32 done
# 2025-01-03 18:47:30,323 [DEBUG] MCTS simulation 3/32 done
# 2025-01-03 18:47:30,329 [DEBUG] MCTS simulation 4/32 done
# 2025-01-03 18:47:30,333 [DEBUG] MCTS simulation 5/32 done
# 2025-01-03 18:47:30,338 [DEBUG] MCTS simulation 6/32 done
# 2025-01-03 18:47:30,342 [DEBUG] MCTS simulation 7/32 done
# 2025-01-03 18:47:30,347 [DEBUG] MCTS simulation 8/32 done
# 2025-01-03 18:47:30,351 [DEBUG] MCTS simulation 9/32 done
# 2025-01-03 18:47:30,355 [DEBUG] MCTS simulation 10/32 done
# 2025-01-03 18:47:30,358 [DEBUG] MCTS simulation 11/32 done
# 2025-01-03 18:47:30,364 [DEBUG] MCTS simulation 12/32 done
